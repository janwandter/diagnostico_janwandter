# %% [markdown]
# # Procesamiento de datos
#
# Descargamos las librerias necesarias

# %%
# !pip install pandas --quiet

# %% [markdown]
# Importamos las librerias

# %%
import pandas as pd
import json

# %% [markdown]
# Pasamos json a un dataframe de pandas

# %%
df_tweets = pd.read_json("farmers-protest-tweets-2021-03-5.json", lines=True)
df_tweets.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/ShashiRajbhar6/status/1376...
# 1  https://twitter.com/kaursuk06272818/status/137...
# 2  https://twitter.com/kaursuk06272818/status/137...
# 3  https://twitter.com/SukhdevSingh_/status/13767...
# 4  https://twitter.com/Davidmu66668113/status/137...
#
#                        date  \
# 0 2021-03-30 03:33:46+00:00
# 1 2021-03-30 03:33:23+00:00
# 2 2021-03-30 03:31:00+00:00
# 3 2021-03-30 03:30:45+00:00
# 4 2021-03-30 03:30:30+00:00
#
#                                              content  \
# 0                       Support 👇\n\n#FarmersProtest
# 1  Supporting farmers means supporting our countr...
# 2  Support farmers if you are related to food #St...
# 3  #StopHateAgainstFarmers support #FarmersProtes...
# 4  You hate farmers I hate you, \nif you love the...
#
#                                      renderedContent                   id  \
# 0                       Support 👇\n\n#FarmersProtest  1376739399593910273
# 1  Supporting farmers means supporting our countr...  1376739306287427584
# 2  Support farmers if you are related to food #St...  1376738704128020488
# 3  #StopHateAgainstFarmers support #FarmersProtes...  1376738640542400518
# 4  You hate farmers I hate you, \nif you love the...  1376738579171344386
#
#                                                 user outlinks tcooutlinks  \
# 0  {'username': 'ShashiRajbhar6', 'displayname': ...       []          []
# 1  {'username': 'kaursuk06272818', 'displayname':...       []          []
# 2  {'username': 'kaursuk06272818', 'displayname':...       []          []
# 3  {'username': 'SukhdevSingh_', 'displayname': '...       []          []
# 4  {'username': 'Davidmu66668113', 'displayname':...       []          []
#
#    replyCount  retweetCount  ...  quoteCount       conversationId  lang  \
# 0           0             0  ...           0  1376739399593910273    en
# 1           0             0  ...           0  1376739306287427584    en
# 2           0             0  ...           0  1376738704128020488    en
# 3           0             1  ...           0  1376738640542400518    en
# 4           0             0  ...           0  1376738579171344386    en
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
#
#                              sourceUrl          sourceLabel  \
# 0  http://twitter.com/download/android  Twitter for Android
# 1  http://twitter.com/download/android  Twitter for Android
# 2  http://twitter.com/download/android  Twitter for Android
# 3  http://twitter.com/download/android  Twitter for Android
# 4  http://twitter.com/download/android  Twitter for Android
#
#                                                media retweetedTweet  \
# 0                                               None            NaN
# 1  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 2  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 3                                               None            NaN
# 4                                               None            NaN
#
#    quotedTweet mentionedUsers
# 0         None           None
# 1         None           None
# 2         None           None
# 3         None           None
# 4         None           None
#
# [5 rows x 21 columns]

# %%
def main (df):
    new_input = True
    print("Bienvenido/a a InfoTwitter")
    while (new_input):
        print(f"""¿Que quieres saber?
                [1] Top 10 tweets con más retweet
                [2] Top 10 usuarios con más tweets
                [3] Top 10 dias con más tweets
                [4] Top 10 hashtags
                [0] Salir
                """)
        choice = input()
        if not choice.isdigit():
            error_handler(1)
        else:
            choice = int(choice)
            if choice < 0 or choice > 4:
                error_handler(1)
            elif choice == 0:
                new_input = False
            else:
                funct[choice - 1](df)
                
def error_handler(_id):
    if _id == 1:
        print("Por favor introduzca un número entre 0 y 4")
    else:
        print("Unexpected Error")
    
def more_retweets(df):
    df_top_retweets = df.sort_values("retweetCount", ascending=False).iloc[:10]
    display(df_top_retweets)
    
def user_more_tweets(df):
    df_top_user = pd.json_normalize(df['user'])
    df_top_user = df_top_user.groupby(['username'])['id'].count().reset_index(name='Tweets')
    df_top_user = df_top_user.sort_values(['Tweets'], ascending=False).iloc[:10]
    display(df_top_user)

def dates_more_tweets(df):
    df_top_dates = df.groupby([df["date"].dt.date]).count().reset_index(name='Tweets')
    display(df_top_dates)
    
def top_hashtags(df):
    pass

            
funct = [more_retweets, user_more_tweets, dates_more_tweets, top_hashtags]

main(df_tweets)
# Out:
# Bienvenido/a a InfoTwitter
# ¿Que quieres saber?
#                 [1] Top 10 tweets con más retweet
#                 [2] Top 10 usuarios con más tweets
#                 [3] Top 10 dias con más tweets
#                 [4] Top 10 hashtags
#                 [0] Salir
#
# 3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-1273203a6af0> in <module>
#      49 funct = [more_retweets, user_more_tweets, dates_more_tweets, top_hashtags]
#      50
# ---> 51 main(df_tweets)
#
# <ipython-input-17-1273203a6af0> in main(df)
#      20                 new_input = False
#      21             else:
# ---> 22                 funct[choice - 1](df)
#      23
#      24 def error_handler(_id):
#
# <ipython-input-17-1273203a6af0> in dates_more_tweets(df)
#      39
#      40 def dates_more_tweets(df):
# ---> 41     df_top_dates = df[df["date"].dt.date]
#      42     df_top_dates = df_top_dates.groupby([df_top_dates.index.date]).count().reset_index(name='Tweets')
#      43     display(df_top_dates)
#
# c:\users\janwandter\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# c:\users\janwandter\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5780             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5781
# -> 5782         self._raise_if_missing(keyarr, indexer, axis_name)
#    5783
#    5784         keyarr = self.take(indexer)
#
# c:\users\janwandter\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5840                 if use_interval_msg:
#    5841                     key = list(key)
# -> 5842                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5843
#    5844             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index([2021-03-30, 2021-03-30, 2021-03-30, 2021-03-30, 2021-03-30, 2021-03-30,\n       2021-03-30, 2021-03-30, 2021-03-30, 2021-03-30,\n       ...\n       2021-02-01, 2021-02-01, 2021-02-01, 2021-02-01, 2021-02-01, 2021-02-01,\n       2021-02-01, 2021-02-01, 2021-02-01, 2021-02-01],\n      dtype='object', length=419507)] are in the [columns]"
