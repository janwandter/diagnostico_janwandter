# %% [markdown]
# # Procesamiento de datos
#
# Descargamos las librerias necesarias

# %%
# !pip install pandas --quiet

# %% [markdown]
# Importamos las librerias

# %%
import pandas as pd
import json

# %% [markdown]
# Pasamos json a un dataframe de pandas

# %%
df_tweets = pd.read_json("farmers-protest-tweets-2021-03-5.json", lines=True)
df_tweets.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/ShashiRajbhar6/status/1376...
# 1  https://twitter.com/kaursuk06272818/status/137...
# 2  https://twitter.com/kaursuk06272818/status/137...
# 3  https://twitter.com/SukhdevSingh_/status/13767...
# 4  https://twitter.com/Davidmu66668113/status/137...
#
#                        date  \
# 0 2021-03-30 03:33:46+00:00
# 1 2021-03-30 03:33:23+00:00
# 2 2021-03-30 03:31:00+00:00
# 3 2021-03-30 03:30:45+00:00
# 4 2021-03-30 03:30:30+00:00
#
#                                              content  \
# 0                       Support 👇\n\n#FarmersProtest
# 1  Supporting farmers means supporting our countr...
# 2  Support farmers if you are related to food #St...
# 3  #StopHateAgainstFarmers support #FarmersProtes...
# 4  You hate farmers I hate you, \nif you love the...
#
#                                      renderedContent                   id  \
# 0                       Support 👇\n\n#FarmersProtest  1376739399593910273
# 1  Supporting farmers means supporting our countr...  1376739306287427584
# 2  Support farmers if you are related to food #St...  1376738704128020488
# 3  #StopHateAgainstFarmers support #FarmersProtes...  1376738640542400518
# 4  You hate farmers I hate you, \nif you love the...  1376738579171344386
#
#                                                 user outlinks tcooutlinks  \
# 0  {'username': 'ShashiRajbhar6', 'displayname': ...       []          []
# 1  {'username': 'kaursuk06272818', 'displayname':...       []          []
# 2  {'username': 'kaursuk06272818', 'displayname':...       []          []
# 3  {'username': 'SukhdevSingh_', 'displayname': '...       []          []
# 4  {'username': 'Davidmu66668113', 'displayname':...       []          []
#
#    replyCount  retweetCount  ...  quoteCount       conversationId  lang  \
# 0           0             0  ...           0  1376739399593910273    en
# 1           0             0  ...           0  1376739306287427584    en
# 2           0             0  ...           0  1376738704128020488    en
# 3           0             1  ...           0  1376738640542400518    en
# 4           0             0  ...           0  1376738579171344386    en
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
#
#                              sourceUrl          sourceLabel  \
# 0  http://twitter.com/download/android  Twitter for Android
# 1  http://twitter.com/download/android  Twitter for Android
# 2  http://twitter.com/download/android  Twitter for Android
# 3  http://twitter.com/download/android  Twitter for Android
# 4  http://twitter.com/download/android  Twitter for Android
#
#                                                media retweetedTweet  \
# 0                                               None            NaN
# 1  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 2  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 3                                               None            NaN
# 4                                               None            NaN
#
#    quotedTweet mentionedUsers
# 0         None           None
# 1         None           None
# 2         None           None
# 3         None           None
# 4         None           None
#
# [5 rows x 21 columns]

# %%
def main (df):
    new_input = True
    print("Bienvenido/a a InfoTwitter")
    while (new_input):
        print(f"""¿Que quieres saber?
                [1] Top 10 tweets con más retweet
                [2] Top 10 usuarios con más tweets
                [3] Top 10 dias con más tweets
                [4] Top 10 hashtags
                [0] Salir
                """)
        choice = input()
        if not choice.isdigit():
            error_handler(1)
        else:
            choice = int(choice)
            if choice < 0 or choice > 4:
                error_handler(1)
            elif choice == 0:
                new_input = False
            else:
                funct[choice - 1](df)
                
def error_handler(_id):
    if _id == 1:
        print("Por favor introduzca un número entre 0 y 4")
    else:
        print("Unexpected Error")
    
def more_retweets(df):
    df_top_retweets = df.sort_values("retweetCount", ascending=False).iloc[:10]
    display(df_top_retweets)
    
def user_more_tweets(df):
    pass

def dates_more_tweets(df):
    pass
    
def top_hashtags(df):
    pass

            
funct = [more_retweets, user_more_tweets, dates_more_tweets, top_hashtags]

main(df_tweets)
# Out:
# Bienvenido/a a InfoTwitter
# ¿Que quieres saber?
#                 [1] Top 10 tweets con más retweet
#                 [2] Top 10 usuarios con más tweets
#                 [3] Top 10 dias con más tweets
#                 [4] Top 10 hashtags
#                 [0] Salir
#
# 1
#                                                       url  \
# 0       https://twitter.com/ShashiRajbhar6/status/1376...
# 255334  https://twitter.com/dontcompareYT/status/13573...
# 255333  https://twitter.com/jashn_nagra/status/1357341...
# 255332  https://twitter.com/ashwanhanda_inc/status/135...
# 255331  https://twitter.com/GaganKa48075621/status/135...
# 255330  https://twitter.com/SindyBrar/status/135734160...
# 255329  https://twitter.com/SimranM34987728/status/135...
# 255328  https://twitter.com/KhalSir/status/13573416240...
# 255327  https://twitter.com/sewaki12/status/1357341634...
# 255326  https://twitter.com/SinghsTwo/status/135734164...
#
#                             date  \
# 0      2021-03-30 03:33:46+00:00
# 255334 2021-02-04 14:53:44+00:00
# 255333 2021-02-04 14:53:44+00:00
# 255332 2021-02-04 14:53:48+00:00
# 255331 2021-02-04 14:53:50+00:00
# 255330 2021-02-04 14:53:52+00:00
# 255329 2021-02-04 14:53:55+00:00
# 255328 2021-02-04 14:53:56+00:00
# 255327 2021-02-04 14:53:58+00:00
# 255326 2021-02-04 14:54:01+00:00
#
#                                                   content  \
# 0                            Support 👇\n\n#FarmersProtest
# 255334  @TheRock @ProjectRock @UnderArmour @DICKS wait...
# 255333  @YUVSTRONG12 Go on the ground and learn what a...
# 255332  #FarmersProtest \n            "Great Salute"\n...
# 255331             @GretaThunberg #FarmersProtest AMAZING
# 255330  Omg this is beyond Stupidity!!!! \n#FarmersPro...
# 255329  @GretaThunberg We need more supporters like yo...
# 255328  "Let us deal with the issue ourselves"\n\n👀👌🏽🙈...
# 255327  thank so much @vanessa_vash ❤️#farmersprotest ...
# 255326             @GretaThunberg Respect #FarmersProtest
#
#                                           renderedContent  \
# 0                            Support 👇\n\n#FarmersProtest
# 255334  @TheRock @ProjectRock @UnderArmour @DICKS wait...
# 255333  @YUVSTRONG12 Go on the ground and learn what a...
# 255332  #FarmersProtest \n            "Great Salute"\n...
# 255331             @GretaThunberg #FarmersProtest AMAZING
# 255330  Omg this is beyond Stupidity!!!! \n#FarmersPro...
# 255329  @GretaThunberg We need more supporters like yo...
# 255328  "Let us deal with the issue ourselves"\n\n👀👌🏽🙈...
# 255327  thank so much @vanessa_vash ❤️#farmersprotest ...
# 255326             @GretaThunberg Respect #FarmersProtest
#
#                          id  \
# 0       1376739399593910273
# 255334  1357341574158446593
# 255333  1357341577463517184
# 255332  1357341591543771136
# 255331  1357341602885238790
# 255330  1357341609407377409
# 255329  1357341623621877762
# 255328  1357341624049668099
# 255327  1357341634996838402
# 255326  1357341646535335951
#
#                                                      user  \
# 0       {'username': 'ShashiRajbhar6', 'displayname': ...
# 255334  {'username': 'dontcompareYT', 'displayname': '...
# 255333  {'username': 'jashn_nagra', 'displayname': 'ਸ....
# 255332  {'username': 'ashwanhanda_inc', 'displayname':...
# 255331  {'username': 'GaganKa48075621', 'displayname':...
# 255330  {'username': 'SindyBrar', 'displayname': 'Sind...
# 255329  {'username': 'SimranM34987728', 'displayname':...
# 255328  {'username': 'KhalSir', 'displayname': '𝙺𝚊𝚕𝚠𝚒𝚗...
# 255327  {'username': 'sewaki12', 'displayname': 'Gurse...
# 255326  {'username': 'SinghsTwo', 'displayname': '2Sin...
#
#                                                  outlinks  \
# 0                                                      []
# 255334                                                 []
# 255333                                                 []
# 255332                                                 []
# 255331                                                 []
# 255330  [https://twitter.com/pbhushan1/status/13572713...
# 255329                                                 []
# 255328  [https://en.m.wikipedia.org/wiki/List_of_massa...
# 255327  [https://twitter.com/vanessa_vash/status/13572...
# 255326                                                 []
#
#                       tcooutlinks  replyCount  retweetCount  ...  quoteCount  \
# 0                              []           0             0  ...           0
# 255334                         []           0             0  ...           0
# 255333                         []           0             0  ...           0
# 255332                         []           0             0  ...           0
# 255331                         []           0             0  ...           0
# 255330  [https://t.co/qNylQLd6c2]           0             0  ...           0
# 255329                         []           0             0  ...           0
# 255328  [https://t.co/tmvICyd2vm]           0             0  ...           0
# 255327  [https://t.co/mJe0HbaczF]           0             0  ...           0
# 255326                         []           0             0  ...           0
#
#              conversationId  lang  \
# 0       1376739399593910273    en
# 255334  1357319448466579457    en
# 255333  1357236005514842114    en
# 255332  1357341591543771136    en
# 255331  1357282507616645122    en
# 255330  1357341609407377409    en
# 255329  1357282507616645122    en
# 255328  1357341624049668099    en
# 255327  1357341634996838402    en
# 255326  1357282507616645122    en
#
#                                                    source  \
# 0       <a href="http://twitter.com/download/android" ...
# 255334  <a href="http://twitter.com/download/iphone" r...
# 255333  <a href="http://twitter.com/download/iphone" r...
# 255332  <a href="http://twitter.com/download/android" ...
# 255331  <a href="https://mobile.twitter.com" rel="nofo...
# 255330  <a href="https://mobile.twitter.com" rel="nofo...
# 255329  <a href="http://twitter.com/download/iphone" r...
# 255328  <a href="http://twitter.com/download/android" ...
# 255327  <a href="http://twitter.com/download/android" ...
# 255326  <a href="http://twitter.com/download/iphone" r...
#
#                                   sourceUrl          sourceLabel media  \
# 0       http://twitter.com/download/android  Twitter for Android  None
# 255334   http://twitter.com/download/iphone   Twitter for iPhone  None
# 255333   http://twitter.com/download/iphone   Twitter for iPhone  None
# 255332  http://twitter.com/download/android  Twitter for Android  None
# 255331           https://mobile.twitter.com      Twitter Web App  None
# 255330           https://mobile.twitter.com      Twitter Web App  None
# 255329   http://twitter.com/download/iphone   Twitter for iPhone  None
# 255328  http://twitter.com/download/android  Twitter for Android  None
# 255327  http://twitter.com/download/android  Twitter for Android  None
# 255326   http://twitter.com/download/iphone   Twitter for iPhone  None
#
#        retweetedTweet                                        quotedTweet  \
# 0                 NaN                                               None
# 255334            NaN                                               None
# 255333            NaN                                               None
# 255332            NaN                                               None
# 255331            NaN                                               None
# 255330            NaN  {'url': 'https://twitter.com/pbhushan1/status/...
# 255329            NaN                                               None
# 255328            NaN                                               None
# 255327            NaN  {'url': 'https://twitter.com/vanessa_vash/stat...
# 255326            NaN                                               None
#
#                                            mentionedUsers
# 0                                                    None
# 255334  [{'username': 'TheRock', 'displayname': 'Dwayn...
# 255333  [{'username': 'YUVSTRONG12', 'displayname': 'Y...
# 255332                                               None
# 255331  [{'username': 'GretaThunberg', 'displayname': ...
# 255330                                               None
# 255329  [{'username': 'GretaThunberg', 'displayname': ...
# 255328                                               None
# 255327  [{'username': 'vanessa_vash', 'displayname': '...
# 255326  [{'username': 'GretaThunberg', 'displayname': ...
#
# [10 rows x 21 columns]
# ¿Que quieres saber?
#                 [1] Top 10 tweets con más retweet
#                 [2] Top 10 usuarios con más tweets
#                 [3] Top 10 dias con más tweets
#                 [4] Top 10 hashtags
#                 [0] Salir
#
# 0
